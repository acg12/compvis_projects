# %% [markdown]
# NIM: 2440021451
#
# Nama: Oei Angela Christabel Gunawan

# %% [markdown]
# # Gray-Level Slicing

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### First approach (left picture)
